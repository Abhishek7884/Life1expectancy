# %%
import os
os.chdir("C:/Users/Shubham/Desktop/data sets")#desktop dataset

# %%
import pandas as pd
data2=pd.read_csv("Life Expectancy Data.csv")
data2.head()
# Out:
#    infant deaths  Alcohol  Hepatitis B  Measles    BMI   Polio  Diphtheria   \
# 0             62     0.01         65.0      1154   19.1    6.0         65.0
# 1             64     0.01         62.0       492   18.6   58.0         62.0
# 2             66     0.01         64.0       430   18.1   62.0         64.0
# 3             69     0.01         67.0      2787   17.6   67.0         67.0
# 4             71     0.01         68.0      3013   17.2   68.0         68.0
#
#     HIV/AIDS         GDP  Life expectancy
# 0        0.1  584.259210              65.0
# 1        0.1  612.696514              59.9
# 2        0.1  631.744976              59.9
# 3        0.1  669.959000              59.5
# 4        0.1   63.537231              59.2

# %%
data2.describe()
data2.columns
# Out:
# Index(['infant deaths', 'Alcohol', 'Hepatitis B', 'Measles ', ' BMI ', 'Polio',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Life expectancy '],
#       dtype='object')

# %%
data2.dtypes
# Out:
# infant deaths         int64
# Alcohol             float64
# Hepatitis B         float64
# Measles               int64
#  BMI                float64
# Polio               float64
# Diphtheria          float64
#  HIV/AIDS           float64
# GDP                 float64
# Life expectancy     float64
# dtype: object

# %%
data2.corr()
# Out:
#                   infant deaths   Alcohol  Hepatitis B  Measles       BMI   \
# infant deaths          1.000000 -0.115638    -0.223566  0.501128 -0.227279
# Alcohol               -0.115638  1.000000     0.087549 -0.051827  0.330408
# Hepatitis B           -0.223566  0.087549     1.000000 -0.120529  0.150380
# Measles                0.501128 -0.051827    -0.120529  1.000000 -0.175977
#  BMI                  -0.227279  0.330408     0.150380 -0.175977  1.000000
# Polio                 -0.170689  0.221734     0.486171 -0.136166  0.284569
# Diphtheria            -0.175171  0.222020     0.611495 -0.141882  0.283147
#  HIV/AIDS              0.025231 -0.048845    -0.112675  0.030899 -0.243717
# GDP                   -0.108427  0.354712     0.083903 -0.076466  0.301557
# Life expectancy       -0.196557  0.404877     0.256762 -0.157586  0.567694
#
#                      Polio  Diphtheria    HIV/AIDS       GDP  Life expectancy
# ...

# %%
data2.cov()
# Out:
#                   infant deaths       Alcohol   Hepatitis B      Measles   \
# infant deaths      13906.659712    -56.279888   -586.667508  6.776735e+05
# Alcohol              -56.279888     16.422048      8.836352 -2.454997e+03
# Hepatitis B         -586.667508      8.836352    628.505682 -2.881926e+04
# Measles           677673.513493  -2454.997328 -28819.257385  1.314983e+08
#  BMI                -540.221027     26.750358     75.201205 -4.067260e+04
# Polio               -473.067997     20.983742    265.456093 -3.669537e+04
# Diphtheria          -491.478667     21.392451    328.878514 -3.870720e+04
#  HIV/AIDS             15.108649     -1.035875    -14.469408  1.799181e+03
# GDP              -195797.072662  20653.294648  26819.368380 -1.209813e+07
# Life expectancy     -221.108419     15.664345     54.122359 -1.723845e+04
#
#                           BMI          Polio   Diphtheria       HIV/AIDS  \
# infant deaths      -540.221027   -473.067997   -491.478667     15.108649
# ...

# %%
data2.isnull().sum()
# Out:
# infant deaths         0
# Alcohol             194
# Hepatitis B         553
# Measles               0
#  BMI                 34
# Polio                19
# Diphtheria           19
#  HIV/AIDS             0
# GDP                 448
# Life expectancy      10
# dtype: int64

# %%
df1=pd.DataFrame(data2)
cols=['infant deaths', 'Alcohol', 'Hepatitis B', 'Measles ', ' BMI ', 'Polio',
       'Diphtheria ', ' HIV/AIDS', 'GDP', 'Life expectancy ']
df1[cols] = df1[cols].fillna(df1.mean().iloc[0])

# %%
df1.isnull().sum()
# Out:
# infant deaths       0
# Alcohol             0
# Hepatitis B         0
# Measles             0
#  BMI                0
# Polio               0
# Diphtheria          0
#  HIV/AIDS           0
# GDP                 0
# Life expectancy     0
# dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
data2['Life expectancy '].hist(bins=10)

# %%
_=plt.scatter(df1[' BMI '], df1['Life expectancy '],  color='black')
_=plt.title('BMI vs life lived')
_=plt.xlabel('BMI')
_=plt.ylabel('age lived')
_=plt.xticks(())
_=plt.yticks(())
plt.show()

# %%
df1.boxplot(column='Alcohol')

# %%
_=plt.scatter(df1[' BMI '], df1['Life expectancy '],  color='black')
_=plt.title('BMI vs life lived')
_=plt.xlabel('BMI')
_=plt.ylabel('age lived')
_=plt.xticks(())
_=plt.yticks(())
plt.show()

# %%
df1.boxplot(column=' BMI ')

# %%
_=plt.scatter(df1[' HIV/AIDS'], df1['Life expectancy '],  color='black')
_=plt.title('aids vs life lived')
_=plt.xlabel('aids index')
_=plt.ylabel('age lived')
_=plt.xticks(())
_=plt.yticks(())
plt.show()

# %%
df1.boxplot(column=' HIV/AIDS')

# %%
_=plt.scatter(df1['Measles '], df1['Life expectancy '],  color='black')
_=plt.title('measeles vs life lived')
_=plt.xlabel('measles  index')
_=plt.ylabel('age lived')
_=plt.xticks(())
_=plt.yticks(())
plt.show()

# %%
df1.boxplot(column='Measles ')

# %%
df1.boxplot(column='GDP')

# %%
_=plt.scatter(df1['GDP'], df1['Life expectancy '],  color='black')
_=plt.title('gdp vs life lived')
_=plt.xlabel('GDP  index')
_=plt.ylabel('age lived')
_=plt.xticks(())
_=plt.yticks(())
plt.show()

# %%
_=plt.scatter(df1['Diphtheria '], df1['Life expectancy '],  color='black')
_=plt.title('diphtheria vs life lived')
_=plt.xlabel('diphthria  index')
_=plt.ylabel('age lived')
_=plt.xticks(())
_=plt.yticks(())
plt.show()

# %%
df1.boxplot(column='Diphtheria ')

# %%
import seaborn as sns
sns.pairplot(df1)

# %%
sns.distplot(df1['GDP'])

# %%
sns.distplot(df1['GDP'])

# %%
sns.distplot(df1[' HIV/AIDS'])

# %%
sns.distplot(df1['Polio'])

# %%
sns.distplot(df1['Diphtheria '])

# %%
sns.distplot(df1[' BMI '])

# %%
df1=df1.drop(['infant deaths', 'Hepatitis B', 'Measles ', ],axis=1)
df1
# Out:
#         Alcohol   BMI   Polio  Diphtheria    HIV/AIDS          GDP  \
# 0      0.010000   19.1    6.0         65.0        0.1   584.259210
# 1      0.010000   18.6   58.0         62.0        0.1   612.696514
# 2      0.010000   18.1   62.0         64.0        0.1   631.744976
# 3      0.010000   17.6   67.0         67.0        0.1   669.959000
# 4      0.010000   17.2   68.0         68.0        0.1    63.537231
# 5      0.010000   16.7   66.0         66.0        0.1   553.328940
# 6      0.010000   16.2   63.0         63.0        0.1   445.893298
# 7      0.030000   15.7   64.0         64.0        0.1   373.361116
# 8      0.020000   15.2   63.0         63.0        0.1   369.835796
# 9      0.030000   14.7   58.0         58.0        0.1   272.563770
# 10     0.020000   14.2   58.0         58.0        0.1    25.294130
# 11     0.020000   13.8    5.0          5.0        0.1   219.141353
# 12     0.010000   13.4   41.0         41.0        0.1   198.728544
# ...

# %%
x=df1.iloc[:,1]

y=df1.iloc[:,-1]

# %%
x_var=df1[[' BMI ']]
y_var=df1[ 'Life expectancy ']
import statsmodels.api as sm
model=sm.OLS(y_var,x_var).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:       Life expectancy    R-squared:                       0.832
# Model:                            OLS   Adj. R-squared:                  0.832
# Method:                 Least Squares   F-statistic:                 1.459e+04
# Date:                Thu, 20 Jun 2019   Prob (F-statistic):               0.00
# Time:                        22:07:33   Log-Likelihood:                -14017.
# No. Observations:                2938   AIC:                         2.804e+04
# Df Residuals:                    2937   BIC:                         2.804e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
#  BMI           1.4766      0.012    120.791      0.000       1.453       1.501
# ...

# %%
from sklearn import model_selection, neighbors
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.1,random_state=5)

# %%
features = x_train.values.reshape(-1,1)

# %%
labels = y_train.values.reshape(-1,1)

# %%
X=features
y=labels

# %%
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(X,y)

# %%
accuracy=model.score(X,y)
print('Accuracy of the model:', accuracy)
# Out:
# Accuracy of the model: 0.2796667844091665

# %%
x=df1.iloc[:,0:6]
y=df1.iloc[:,-1]

# %%
x
# Out:
#         Alcohol   BMI   Polio  Diphtheria    HIV/AIDS          GDP
# 0      0.010000   19.1    6.0         65.0        0.1   584.259210
# 1      0.010000   18.6   58.0         62.0        0.1   612.696514
# 2      0.010000   18.1   62.0         64.0        0.1   631.744976
# 3      0.010000   17.6   67.0         67.0        0.1   669.959000
# 4      0.010000   17.2   68.0         68.0        0.1    63.537231
# 5      0.010000   16.7   66.0         66.0        0.1   553.328940
# 6      0.010000   16.2   63.0         63.0        0.1   445.893298
# 7      0.030000   15.7   64.0         64.0        0.1   373.361116
# 8      0.020000   15.2   63.0         63.0        0.1   369.835796
# 9      0.030000   14.7   58.0         58.0        0.1   272.563770
# 10     0.020000   14.2   58.0         58.0        0.1    25.294130
# 11     0.020000   13.8    5.0          5.0        0.1   219.141353
# 12     0.010000   13.4   41.0         41.0        0.1   198.728544
# ...

# %%
y
# Out:
# 0       65.0
# 1       59.9
# 2       59.9
# 3       59.5
# 4       59.2
# 5       58.8
# 6       58.6
# 7       58.1
# 8       57.5
# 9       57.3
# 10      57.3
# 11      57.0
# 12      56.7
# 13      56.2
# 14      55.3
# 15      54.8
# 16      77.8
# 17      77.5
# 18      77.2
# 19      76.9
# 20      76.6
# 21      76.2
# 22      76.1
# 23      75.3
# 24      75.9
# 25      74.2
# 26      73.5
# 27      73.0
# 28      72.8
# 29      73.3
#         ...
# 2908    63.0
# 2909    59.2
# 2910    58.2
# 2911    58.0
# 2912    57.4
# 2913    55.7
# 2914    52.6
# 2915    58.0
# 2916    49.3
# 2917    47.9
# 2918    46.4
# 2919    45.5
# 2920    44.6
# 2921    43.8
# 2922    67.0
# 2923    59.2
# 2924    58.0
# 2925    56.6
# 2926    54.9
# 2927    52.4
# 2928    50.0
# 2929    48.2
# 2930    46.6
# 2931    45.4
# 2932    44.6
# 2933    44.3
# 2934    44.5
# 2935    44.8
# 2936    45.3
# 2937    46.0
# Name: Life expectancy , Length: 2938, dtype: float64

# %%
from sklearn import preprocessing
minmax=preprocessing.MinMaxScaler(feature_range=(0,1))
minmax.fit(x).transform(x)
# Out:
# array([[0.00000000e+00, 2.09733488e-01, 3.12500000e-02, 6.49484536e-01,
#         0.00000000e+00, 4.88858501e-03],
#        [0.00000000e+00, 2.03939745e-01, 5.72916667e-01, 6.18556701e-01,
#         0.00000000e+00, 5.12721093e-03],
#        [0.00000000e+00, 1.98146002e-01, 6.14583333e-01, 6.39175258e-01,
#         0.00000000e+00, 5.28705227e-03],
#        ...,
#        [1.45903728e-01, 2.93163384e-01, 7.29166667e-01, 7.11340206e-01,
#         7.86138614e-01, 4.67118357e-04],
#        [5.64469176e-02, 2.88528389e-01, 7.60416667e-01, 7.52577320e-01,
#         8.31683168e-01, 4.58925145e-03],
#        [5.51265218e-02, 2.83893395e-01, 7.81250000e-01, 7.83505155e-01,
#         8.59405941e-01, 4.57894330e-03]])

# %%
x_var=df1[['Alcohol', ' BMI ', 'Polio', 'Diphtheria ', ' HIV/AIDS', 'GDP']]
y_var=df1[ 'Life expectancy ']
import statsmodels.api as sm
model=sm.OLS(y_var,x_var).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:       Life expectancy    R-squared:                       0.960
# Model:                            OLS   Adj. R-squared:                  0.960
# Method:                 Least Squares   F-statistic:                 1.168e+04
# Date:                Thu, 20 Jun 2019   Prob (F-statistic):               0.00
# Time:                        22:07:35   Log-Likelihood:                -11919.
# No. Observations:                2938   AIC:                         2.385e+04
# Df Residuals:                    2932   BIC:                         2.389e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Alcohol         0.2574      0.035      7.293      0.000       0.188       0.327
# ...

# %%
#Splitting the dataset into Training set and Test set
from sklearn import model_selection, neighbors
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.1,random_state=5)

# %%
features = x_train.iloc[:,:].values

# %%
features
# Out:
# array([[3.03039483e+01, 3.03039483e+01, 3.03039483e+01, 3.03039483e+01,
#         3.00000000e+00, 3.03039483e+01],
#        [1.00000000e-02, 5.40000000e+01, 9.30000000e+01, 9.30000000e+01,
#         1.00000000e-01, 3.75442638e+02],
#        [7.01000000e+00, 1.98000000e+01, 6.30000000e+01, 6.00000000e+00,
#         2.50000000e+00, 3.34784485e+03],
#        ...,
#        [2.91000000e+00, 4.30000000e+01, 9.80000000e+01, 9.90000000e+01,
#         1.00000000e-01, 1.33465190e+03],
#        [2.80000000e-01, 2.17000000e+01, 7.60000000e+01, 8.90000000e+01,
#         4.00000000e-01, 1.16313770e+01],
#        [2.25000000e+00, 1.88000000e+01, 8.30000000e+01, 8.10000000e+01,
#         1.59000000e+01, 1.31541990e+01]])

# %%
labels = y_train.iloc[:].values

# %%
labels=labels

# %%
X=features
y=labels

# %%
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(X,y)

# %%
accuracy=model.score(X,y)
print('Accuracy of the model:', accuracy)
# Out:
# Accuracy of the model: 0.6119274908986194

# %%
predictions = model.predict(X)

# %%
from sklearn.metrics import mean_squared_error, r2_score


print('Slope:' ,model.coef_)
print('Intercept:', model.intercept_)
print("\n")


import numpy as np
rmse = (np.sqrt(mean_squared_error(y,predictions)))
r2 = r2_score(y,predictions)

print("The model performance")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")
# Out:
# Slope: [ 1.09830020e-01  1.31444541e-01  5.99555892e-02  7.37821478e-02
#  -7.27369745e-01  1.69334926e-04]
# Intercept: 52.61298614544154
#
#
# The model performance
# --------------------------------------
# RMSE is 6.125124807459567
# R2 score is 0.6119274908986194

# %%
#Build a Logistic Regression Model
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
lr = LogisticRegression()
y=lr.fit(x_train, y_train)
#lr.fit(x_train,y_train)#dichomous or binary classification.
#lr_acc = cross_val_score(lr, x_train_std, y_train, cv=3, scoring='accuracy', n_jobs=-1)
#lr_proba = cross_val_predict(lr, x_train_std, y_train, cv=3, method='predict_proba')
# Out:
# c:\users\shubham\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-656-df30069a7f2d> in <module>
#       3 from sklearn.model_selection import cross_val_score
#       4 lr = LogisticRegression()
# ----> 5 y=lr.fit(x_train, y_train)
#       6 #lr.fit(x_train,y_train)#dichomous or binary classification.
#       7 #lr_acc = cross_val_score(lr, x_train_std, y_train, cv=3, scoring='accuracy', n_jobs=-1)
#
# c:\users\shubham\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\linear_model\logistic.py in fit(self, X, y, sample_weight)
#    1287         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype, order="C",
# ...

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import cross_val_score
decision_tree_model = DecisionTreeRegressor()
decision_tree_fit = decision_tree_model.fit(x_train, y_train)
#life_features_train, life_features_test, life_labels_train, life_labels_test
#x_train, x_test, y_train, y_test 
decision_tree_score = cross_val_score(decision_tree_fit, x_train, y_train, cv = 5)
print("mean cross validation score: %.2f"  % np.mean(decision_tree_score))
print("score without cv: %.2f" % decision_tree_fit.score(x_train, y_train))
print("R^2 score on the test data %.2f"% r2_score(y_test, decision_tree_fit.predict(x_test)))
# Out:
# mean cross validation score: 0.70
# score without cv: 1.00
# R^2 score on the test data 0.78

# %%
y_pred = decision_tree_model.predict(x_test)
#from sklearn.metrics import accuracy_score, recall_score, roc_auc_score, confusion_matrix

#print("\nAccuracy score: %f" %(accuracy_score(y_test,y_pred) * 100))
#print("Recall score : %f" %(recall_score(y_test, y_pred) * 100))
#print("ROC score : %f\n" %(roc_auc_score(y_test, y_pred) * 100))
#print(confusion_matrix(y_test, y_pred)) #27 out of 114 have no cancer as told by the model.11 told that doctor predicted it has cancer but machine prididcted as it does not have cancer.
#1 data is there where doctor interpre

# %%
y_pred = decision_tree_model.predict(x_test)
#life_features_train, life_features_test, life_labels_train, life_labels_test
#x_train, x_test, y_train, y_test 
accuracy=decision_tree_model.score(x_test,y_test)
print('Accuracy of the model:', accuracy)
# Out:
# Accuracy of the model: 0.7838914124080587

# %%
y_pred
# Out:
# array([55.3, 73.3, 66.7, 69.3, 72.2, 73.5, 76.6, 73.5, 65.7, 71.6, 62.3,
#        66.7, 74.3, 68. , 82. , 59.5, 82.6, 63. , 65.9, 67.6, 77.8, 71.2,
#        73. , 68. , 61.4, 67.8, 77.2, 67.7, 73. , 59.6, 73.1, 75.9, 86. ,
#        75.1, 69. , 53.6, 58.2, 79. , 76.1, 59.9, 73. , 68.9, 86. , 74.3,
#        73.5, 74.1, 71. , 58. , 75. , 77.2, 78.3, 82.7, 75.9, 74.2, 50. ,
#        65.4, 61.1, 79.6, 65.1, 72.9, 62.5, 75.8, 63.3, 79.4, 67. , 73.6,
#        73.1, 56.2, 65.5, 83. , 81.5, 81.1, 74.2, 59.2, 54.3, 81.8, 64.5,
#        57.1, 81.4, 63.7, 76. , 53.2, 64.5, 68. , 73. , 66. , 73. , 74.1,
#        72.3, 47.7, 69.1, 68.8, 72.6, 75.3, 73.7, 67. , 72.7, 73.3, 68.2,
#        74.3, 55.4, 55.6, 71.8, 69.8, 59.5, 74.2, 73.6, 66.2, 54.4, 63.3,
#        79.8, 56.8, 59.8, 65.9, 81.8, 59.7, 77.7, 67.1, 55.7, 67.2, 63.4,
#        56.7, 73.2, 73.1, 69.4, 72.5, 75.5, 81.2, 74.5, 64.7, 85. , 68.6,
#        77. , 55. , 71.8, 78. , 63. , 72.2, 58.7, 79.8, 74.9, 77.5, 77.2,
# ...

# %%
y_test
# Out:
# 1499    56.7
# 1931    75.6
# 2556    68.8
# 2856    69.1
# 2731    78.0
# 1402    73.7
# 227     71.9
# 1393    64.1
# 1383    65.3
# 47      71.3
# 1127    36.3
# 2558    67.3
# 1867    73.2
# 1987    59.6
# 378     76.2
# 607     59.5
# 1323    82.4
# 863     58.5
# 1796    65.8
# 1046    72.9
# 2215    72.0
# 2356    77.2
# 2827    69.2
# 2031    67.5
# 1492    61.1
# 2836    67.3
# 668     77.3
# 2738    67.5
# 1523    73.4
# 1824    64.7
#         ...
# 675     81.0
# 2304    46.2
# 406     56.9
# 467     67.4
# 908     68.3
# 1557    64.3
# 734     52.1
# 1096    56.3
# 622     52.7
# 701     75.2
# 1647    78.2
# 1365    62.1
# 1095    56.7
# 223     73.3
# 266     69.0
# 2687    73.9
# 1072    68.4
# 480     57.3
# 2009    75.3
# 171     73.8
# 1705    68.5
# 1968    76.2
# 2457    64.1
# 2745    67.5
# 51      56.0
# 1266    82.5
# 182     76.0
# 2420    51.4
# 1820    67.0
# 2320    81.4
# Name: Life expectancy , Length: 294, dtype: float64

# %%
from sklearn.metrics import accuracy_score, recall_score, roc_auc_score, confusion_matrix

print("\nAccuracy score: %f" %(decision_tree_model.score(x_test,y_test) * 100))
# Out:
# Accuracy score: 78.389141

# %%
from sklearn.ensemble import RandomForestRegressor
random_forest_model = RandomForestRegressor()
random_forest_fit = random_forest_model.fit(x_train, y_train)
random_forest_score = cross_val_score(random_forest_fit, x_train, y_train, cv = 5)
# Out:
# c:\users\shubham\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
y_predict = random_forest_model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, recall_score, roc_auc_score, confusion_matrix

print("\nAccuracy score of random forest is: %f" %(random_forest_model.score(x_test,y_test) * 100))
# Out:
# Accuracy score of random forest is: 85.266027
